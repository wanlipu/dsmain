# %% [markdown]
# # Python Visualization

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Basic Plotting

# %%
# Basic line plotting
np.random.seed(111)
y = np.random.rand(20)
plt.plot(y)

# %%
np.random.seed(111)
y = np.random.randn(200)
y1 = np.random.randn(200)


# other basic plotting

# histogram
#plt.hist2d(y, y1)
# plt.hist2d(y, y)

# boxplot
#plt.boxplot(y)

# pie
#plt.pie([5,3,6,4], labels = ['China', 'Russia', 'US', 'Brazil'], explode = [0.1, 0, 0, 0])
# bar
# plt.bar([0, 1, 2, 3], [5,3,6,4])

# barh
# plt.barh([0, 1, 2, 3], [5,3,6,4])

# scatter
#plt.scatter(np.random.rand(100), np.random.rand(100))

# errorbar
#plt.errorbar([0,1,2,3], [4,2,4,5], [0.2, 0.3, 0.1, 0.3])

# imshow
# plt.imshow(np.random.randint(0, 100, [20,10]))

# contour(f)
x = y = np.arange(-3.0, 3.0, 0.1)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2
#plt.contourf(X, Y, Z)
plt.pcolor(X, Y, Z)
# plt.pcolormesh(X, Y, Z)
plt.show()

# %%
print X.shape, Y.shape, Z.shape
# Out:
# (60L, 60L) (60L, 60L) (60L, 60L)

# %%
# general parameters
plt.plot(np.random.random(20))
plt.legend(['a simple legend'])
plt.title('New Plot')
plt.xlim([0, 22])
plt.ylim([0, 1.2])
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0, 10, 20])
plt.yticks(np.arange(-0.2, 1.2, 0.1))
plt.show()

# %% [markdown]
# ## Advanced Plotting

# %%
# advanced elements (style & color, c, ls, lw, marker, ms, mfc, mec, m, alpha,
#                    title, xlim, xlabel, xticks,
#                    legend, text, annotate, box, hlines, vlines, axhline, axvline
#                    two plots in one
#                   )
y = np.random.rand(20)
plt.plot(y, c='green', ls='-.', lw=2, marker='o', 
         ms=5, mfc='black', mec='red', alpha=1,
         label='Sales')
#plt.title('First Plot')
#plt.xlabel("Time")
#plt.xlim([0, 25])
#plt.ylim([-0.2, 1.2])
#plt.xticks(np.arange(0, 25, 2))
plt.legend()
#plt.text(14, -0.1, "This year's sale is random")
#plt.annotate(xy=(2, 1), xytext=(3, 1.1), s='First sale')
#plt.hlines(1.0, 0, 12)
plt.axhline(0.5)
#plt.plot(np.random.rand(20))
plt.show()

# %%
plt.plot?

# %%
! pip install pandas_datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.2.1-py2.py3-none-any.whl
# Collecting requests-file (from pandas-datareader)
#   Downloading requests-file-1.4.tar.gz
# Requirement already satisfied (use --upgrade to upgrade): pandas in c:\users\wanli\anaconda2\envs\dato-env\lib\site-packages (from pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): requests in c:\users\wanli\anaconda2\envs\dato-env\lib\site-packages (from pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): six in c:\users\wanli\anaconda2\envs\dato-env\lib\site-packages (from requests-file->pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil in c:\users\wanli\anaconda2\envs\dato-env\lib\site-packages (from pandas->pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): pytz>=2011k in c:\users\wanli\anaconda2\envs\dato-env\lib\site-packages (from pandas->pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.7.0 in c:\users\wanli\anaconda2\envs\dato-env\lib\site-packages (from pandas->pandas-datareader)
# Installing collected packages: requests-file, pandas-datareader
#   Running setup.py install for requests-file
# Successfully installed pandas-datareader-0.2.1 requests-file-1.4
# You are using pip version 7.0.3, however version 8.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
! python -m pip install --upgrade pip
# Out:
# Collecting pip
#   Downloading pip-8.1.1-py2.py3-none-any.whl (1.2MB)
# Installing collected packages: pip
#   Found existing installation: pip 7.0.3
#     Uninstalling pip-7.0.3:
#       Successfully uninstalled pip-7.0.3
# Successfully installed pip-8.1.1
# You are using pip version 7.0.3, however version 8.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Excercize: For investors buy Apple stock at 09/04/2012, when the investors get their investment back?
# 1) use following data, do Pandas operation
# 2) legend 3) reference line 4) annotation
from pandas_datareader import data, wb
import datetime
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2015, 10, 10)
f = web.DataReader("AAPL", 'yahoo', start, end)

# f.index[673]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-40c26306ef0a> in <module>()
#       6 start = datetime.datetime(2010, 1, 1)
#       7 end = datetime.datetime(2015, 10, 10)
# ----> 8 f = web.DataReader("AAPL", 'yahoo', start, end)
#       9
#      10 # f.index[673]
#
# NameError: name 'web' is not defined

# %%
plt.plot(x, y, label='Apple')
plt.legend(loc='best')
plt.hlines(f['Adj Close'][673], x[673], x[1100])
plt.vlines?
plt.annotate(xy=(x[673], y[673]), xytext=(x[673]+10, y[673]+10), s='Current high')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-9dd43d3cab6f> in <module>()
# ----> 1 plt.plot(x, y, label='Apple')
#       2 plt.legend(loc='best')
#       3 plt.hlines(f['Adj Close'][673], x[673], x[1100])
#       4 get_ipython().magic(u'pinfo plt.vlines')
#       5 plt.annotate(xy=(x[673], y[673]), xytext=(x[673]+10, y[673]+10), s='Current high')
#
# C:\Users\Wanli\Anaconda2\envs\dato-env\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3097         ax.hold(hold)
#    3098     try:
# -> 3099         ret = ax.plot(*args, **kwargs)
#    3100         draw_if_interactive()
#    3101     finally:
#
# C:\Users\Wanli\Anaconda2\envs\dato-env\lib\site-packages\matplotlib\axes\_axes.pyc in plot(self, *args, **kwargs)
#    1371         lines = []
#    1372
# -> 1373         for line in self._get_lines(*args, **kwargs):
#    1374             self.add_line(line)
#    1375             lines.append(line)
#
# C:\Users\Wanli\Anaconda2\envs\dato-env\lib\site-packages\matplotlib\axes\_base.pyc in _grab_next_args(self, *args, **kwargs)
#     302                 return
#     303             if len(remaining) <= 3:
# --> 304                 for seg in self._plot_args(remaining, kwargs):
#     305                     yield seg
#     306                 return
#
# C:\Users\Wanli\Anaconda2\envs\dato-env\lib\site-packages\matplotlib\axes\_base.pyc in _plot_args(self, tup, kwargs)
#     280             x = np.arange(y.shape[0], dtype=float)
#     281
# --> 282         x, y = self._xy_from_xy(x, y)
#     283
#     284         if self.command == 'plot':
#
# C:\Users\Wanli\Anaconda2\envs\dato-env\lib\site-packages\matplotlib\axes\_base.pyc in _xy_from_xy(self, x, y)
#     221         y = np.atleast_1d(y)
#     222         if x.shape[0] != y.shape[0]:
# --> 223             raise ValueError("x and y must have same first dimension")
#     224         if x.ndim > 2 or y.ndim > 2:
#     225             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %% [markdown]
# # Objective-Oriented Programming

# %%
# What is an object? 
# What is a Class?
# What is in a Class? 
# (person, professor, student)

# %%
a = 1
print a.__class__
b = 'Python'
print b.__class__
c = lambda x: 2.3 * x % 3
print c.__class__

# %%
# attribute
# methods

# %%
class person(object):
    def __init__(self, age=None, sex=None):
        self._age = age
        self._sex = sex
    def get_age(self):
        return self._age
        # print self._age
    def get_sex(self):
        return self._sex
    def set_age(self, new_age):
        self._age = new_age

    
class professor(person):
    def __init__(self, age=None, sex=None, major=None):
        self._age = age
        self._sex = sex
        self._major = major
    def get_major(self):
        return self._major
    def set_major(self, new_major):
        self._major = new_major

# %%
# Excercise: design a banking accounting system, checking & saving account

# %%
student1 = person()

# %%
print student1._age
# Out:
# None

# %%
# Multiple Plot inside one Axes
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2015, 1, 1)
f = web.DataReader("AAPL", 'yahoo', start, end)
fm = web.DataReader("MSFT", 'yahoo', start, end)

# %%
# get X data, convert to np array, now it is np array with date information
X = np.array(f.index.tolist())
Y = np.array(f['Adj Close'].values)
XM = np.array(fm.index.tolist())
YM = np.array(fm['Adj Close'].values)

# Basic Plot X, Y
# plt.plot(X,Y)
# Looks like the stock price keep increasing!! 
# Start to add some feature .. legend first
plt.plot(X, Y, label='AAPL', marker='.')
plt.plot(XM, YM, label='MSFT', c='green')
plt.legend(loc='upper left') # may change the position
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.xticks(rotation=45)
plt.title('Stock Price of Apple: A great way to invest')

# %%
# Multiple Axes inside one Figure
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax1.plot(X, Y, label='AAPL', marker='.')
ax1.legend(loc='upper left') # may change the position
ax1.set_xlabel('Date')
ax1.set_ylabel('Stock Price')
ax1.set_title('Stock Price of Apple: A great way to invest')

plt.xticks(rotation=45)

ax2 = fig.add_subplot(2,1,2)
ax2.plot(XM, YM, label='MSFT', c='green')
ax2.legend(loc='upper left') # may change the position
ax2.set_xlabel('Date')
ax2.set_ylabel('Stock Price')
ax2.set_title('Stock Price of Apple: A great way to invest')
fig.show()

# %% [markdown]
# ## Matplotlib Principle

# %%
# Hierarchy: Figure, Axes, Artist
fig = plt.figure(dpi=300, figsize=(12, 6))

# get the data
y = np.random.randn(100)

ax1 = fig.add_subplot(1,2,1) # axes
ax1.plot(y, c='red')
# ax1.set_xlabel('Time')
# plt.xlabel('Time')
ax2 = fig.add_subplot(1,2,2)
ax2.hist(y)

ax1.set_xlabel('Time')

# fig.show()
fig.savefig('random.png', dpi=200)

# %%
# Figure level: size, resolution, save

# %%
# Axes level: multiple axes organization
# Hierarchy: Figure, Axes, Artist
# fig = plt.figure(dpi=300, figsize=(8, 4))
# ax1 = plt.subplot2grid?

# %%
# Excercise (get data from Yahoo stock), draw (plot, hist, pie in one graph)
import pandas.io.data as web
import datetime
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2015, 10, 10)
f = web.DataReader("AAPL", 'yahoo', start, end)
fm = web.DataReader("MSFT", 'yahoo', start, end)

# %%
# get X data, convert to np array, now it is np array with date information
X = np.array(f.index.tolist())
Y = np.array(f['Adj Close'].values)
XM = np.array(fm.index.tolist())
YM = np.array(fm['Adj Close'].values)

# %%
# 2 X 2
 
# Upper left, stock daily; Upper right, stock hist (APPLE)
# Lower left, stock daily; Lower right, stock hist (MSFT)
fig = plt.figure(figsize=(8,8))

ax1 = fig.add_subplot(2,2,1)
ax1.plot_date(X, Y, '-')

ax2 = fig.add_subplot(2,2,2)
ax2.hist(Y)

ax3 = fig.add_subplot(2,2,3)
ax3.plot_date(XM, YM, '-')

ax4 = fig.add_subplot(2,2,4)
ax4.hist(YM)

ax2.set_xlim(0, 150)
ax4.set_xlim(0, 150)

fig.show()
# Out:
# C:\Users\Wanli\Anaconda2\envs\dato-env\lib\site-packages\matplotlib\figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
# 1 X 2
 
# Upper left, stock daily; Upper right, stock hist (APPLE)
# Lower left, stock daily; Lower right, stock hist (MSFT)
fig = plt.figure(figsize=(16,8))

ax1 = fig.add_subplot(1,2,1)
ax1.plot_date(X, Y, '-')
ax1.plot_date(XM, YM, '-')

ax2 = fig.add_subplot(1,2,2)
ax2.hist(Y)
ax2.hist(YM)



#ax2.set_xlim(0, 150)
#ax4.set_xlim(0, 150)

fig.show()

# %%
plt.style.use('ggplot')

# %%
plt.style.available
# Out:
# [u'dark_background', u'bmh', u'grayscale', u'ggplot', u'fivethirtyeight']

# %% [markdown]
# ## Exploratory Data Analytics

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# ### Note

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### One discrete variable

# %%
# value_count, bar, pie
# example: survived, sex

# %%
df.Survived.value_counts(normalize = True, dropna = False)
# Out:
# 0    0.616162
# 1    0.383838
# dtype: float64

# %%
plt.bar([0,1], df.Survived.value_counts().values)
# Out:
# <Container object of 2 artists>

# %%
# bar, pie
# Data Generation
X = df.Survived.value_counts().index.tolist()
Y = df.Survived.value_counts().values
fig = plt.figure(figsize=(8, 4))

# Figure Plotting
ax1 = fig.add_subplot(1,2,1)
ax1.bar(X, Y)
ax1.set_title('Survived')
ax1.set_xlabel('Survived or Not')
ax1.set_ylabel('Count')
ax1.set_xticks([0.4, 1.4])
ax1.set_xticklabels(['No...', 'Yes!!'])

ax2 = fig.add_subplot(1,2,2)
ax2.pie(Y, labels=['No...', 'Yes!!!'])

fig.show()

# %% [markdown]
# ### One continuous variable

# %%
# box plot, histogram, Qcut + bar plot
# Age, Fare

# %%
Y = df.Fare.values

# %%
plt.hist(Y)
plt.show()

# %%
v1, v2, v3 = plt.hist(Y)

# %%
v31 = v3[1]

# %% [markdown]
# ### Two discrete variables

# %%
# pivot table, stacked bar plot
# Survived vs Sex

# %% [markdown]
# ### Two continuous variables

# %%
# scatter plot, plot, contour(f), hist2d
# Age vs Fare

# %% [markdown]
# ### One discrete, one continuous variables

# %%
# group-by, stack plot, multiple histogram, violinplot

# %%
# Survived vs Age

# %% [markdown]
# ### Multiple variables (>2)

# %%
# multiple plot in one figure, twinx
# revenue, stock price, date

# %% [markdown]
# ### Pandas fast visualization

# %%
# Series plotting

# %%
# DataFrame plotting
